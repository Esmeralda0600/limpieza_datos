# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
torre = ("../data/raw/002_Torre2.csv")
may = ("../data/raw/29-may-2026.csv")
df_torre = pd.read_csv(torre,
                    index_col=0,
                    parse_dates=True
            )
df_may = pd.read_csv(may,
                     encoding="ISO-8859-1",
                     index_col=11,
                     parse_dates=True)
df_may.index
# Out:
# C:\Users\atlas\AppData\Local\Temp\ipykernel_19652\334871284.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_may = pd.read_csv(may,
# DatetimeIndex(['2026-05-25 13:53:37', '2026-05-25 13:54:37',
#                '2026-05-25 13:55:37', '2026-05-25 13:56:37',
#                '2026-05-25 13:57:37', '2026-05-25 13:58:37',
#                '2026-05-25 13:59:37', '2026-05-25 14:00:37',
#                '2026-05-25 14:01:37', '2026-05-25 14:02:37',
#                ...
#                '2026-05-29 08:53:37', '2026-05-29 08:54:37',
#                '2026-05-29 08:55:37', '2026-05-29 08:56:37',
#                '2026-05-29 08:57:37', '2026-05-29 08:58:37',
#                '2026-05-29 08:59:37', '2026-05-29 09:00:37',
#                '2026-05-29 09:01:37', '2026-05-29 09:02:37'],
# ...

# %%
#concatenar 002_Torre2.csv y 29-mayo-2026.csv 

df_torre.index = pd.to_datetime(df_torre.index, format="mixed", utc=False)
#df_torre.index
concatenar = pd.concat([df_may,df_torre])
concatenar.head()
# Out:
#                      Lectura  Descripción Temperatura Bulbo húmedo  \
# 2026-05-25 13:53:37      1.0          NaN     31.6 °C      21.3 °C
# 2026-05-25 13:54:37      2.0          NaN     31.4 °C      20.6 °C
# 2026-05-25 13:55:37      3.0          NaN     31.6 °C      20.9 °C
# 2026-05-25 13:56:37      4.0          NaN     32.0 °C      21.0 °C
# 2026-05-25 13:57:37      5.0          NaN     31.9 °C      20.9 °C
#
#                     Punto de condensación    % HR     CO      CO2  \
# 2026-05-25 13:53:37               17.3 °C  42.9 %  0 ppm  438 ppm
# 2026-05-25 13:54:37               16.2 °C  40.4 %  0 ppm  429 ppm
# 2026-05-25 13:55:37               16.5 °C  40.5 %  0 ppm  427 ppm
# 2026-05-25 13:56:37               16.6 °C  39.8 %  0 ppm  424 ppm
# 2026-05-25 13:57:37               16.5 °C  39.8 %  0 ppm  422 ppm
#
#                      % aire exterior  Velocidad  Flujo de aire  T03  T04  T05  \
# 2026-05-25 13:53:37              NaN        NaN            NaN  NaN  NaN  NaN
# ...
