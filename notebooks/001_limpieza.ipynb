# %%
import pandas as pd
import matplotlib.pyplot as pyplot
import numpy as np

# %%
may = ("../data/raw/29-may-2026.csv")
torre = ("../data/raw/002_Torre2.csv")
df_may = pd.read_csv(may,
                     encoding="ISO-8859-1",
                     index_col=11,
                     parse_dates=True)

df_may.head()
# Out:
# C:\Users\atlas\AppData\Local\Temp\ipykernel_22340\1236495443.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_may = pd.read_csv(may,
#                      Lectura  Descripción Temperatura Bulbo húmedo  \
# Sello de tiempo
# 2026-05-25 13:53:37        1          NaN     31.6 °C      21.3 °C
# 2026-05-25 13:54:37        2          NaN     31.4 °C      20.6 °C
# 2026-05-25 13:55:37        3          NaN     31.6 °C      20.9 °C
# 2026-05-25 13:56:37        4          NaN     32.0 °C      21.0 °C
# 2026-05-25 13:57:37        5          NaN     31.9 °C      20.9 °C
#
#                     Punto de condensación    % HR     CO      CO2  \
# Sello de tiempo
# 2026-05-25 13:53:37               17.3 °C  42.9 %  0 ppm  438 ppm
# 2026-05-25 13:54:37               16.2 °C  40.4 %  0 ppm  429 ppm
# 2026-05-25 13:55:37               16.5 °C  40.5 %  0 ppm  427 ppm
# 2026-05-25 13:56:37               16.6 °C  39.8 %  0 ppm  424 ppm
# 2026-05-25 13:57:37               16.5 °C  39.8 %  0 ppm  422 ppm
#
#                      % aire exterior  Velocidad  Flujo de aire
# Sello de tiempo
# 2026-05-25 13:53:37              NaN        NaN            NaN
# 2026-05-25 13:54:37              NaN        NaN            NaN
# 2026-05-25 13:55:37              NaN        NaN            NaN
# 2026-05-25 13:56:37              NaN        NaN            NaN
# 2026-05-25 13:57:37              NaN        NaN            NaN

# %%
columnas = df_may.columns
#columnas
df_may = df_may.rename (columns={
    "Temperatura":"Temp",
    "Bulbo húmedo": "BH",
    "Punto de condensación": "PC",
    "% HR": "HR",
    "Sello de tiempo": "Time" 
    })


df_may["Temp"] = df_may["Temp"].replace("°C", "", regex=True)
df_may["BH"] = df_may["BH"].replace("°C", "", regex=True)
df_may["PC"] = df_may["PC"].replace("°C", "", regex=True)
df_may["HR"] = df_may["HR"].replace("%", "", regex=True)

df_may["Temp"] = pd.to_numeric(df_may["Temp"])
df_may["BH"] = pd.to_numeric(df_may["BH"])
df_may["PC"] = pd.to_numeric(df_may["PC"])
df_may["HR"] = pd.to_numeric(df_may["HR"])

df_may = df_may.loc[:,["Lectura", "Temp", "BH", "PC", "HR"]]

df_may = df_may.rename_axis("Time")

#df_may.to_parquet("../data/processed/29-may-2026-limpio.parquet")
#df_may
